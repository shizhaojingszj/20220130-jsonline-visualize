# %%
import seaborn as sns

# %%
# !ls -alhrt --color=auto data
# Out:
# total 16K
# lrwxrwxrwx 1 zhaomeng zhaomeng  169 2月   8 17:07 out.jsonline -> /mnt/GPU1-raid0/zhaomeng-from-GPU3/projects/20220128-fl/Federated_learning/Tdeeppath/temp/20220130-jsonline-visualize/work/74/64cc035b6424e41dbaf9f565273fe0/out.jsonline
# lrwxrwxrwx 1 zhaomeng zhaomeng  173 2月   8 17:08 out.jsonline.png -> /mnt/GPU1-raid0/zhaomeng-from-GPU3/projects/20220128-fl/Federated_learning/Tdeeppath/temp/20220130-jsonline-visualize/work/97/68604acb77554207dbf27b830fe3e8/out.jsonline.png
# drwxrwxr-x 2 zhaomeng zhaomeng 4.0K 2月   8 17:08 .
# drwxrwxr-x 8 zhaomeng zhaomeng 4.0K 2月   9 09:44 ..

# %%
cd /mnt/GPU1-raid0/zhaomeng-from-GPU3/projects/20220128-fl/Federated_learning/Tdeeppath/temp/20220130-jsonline-visualize/work/97/68604acb77554207dbf27b830fe3e8/
# Out:
# /mnt/GPU1-raid0/zhaomeng-from-GPU3/projects/20220128-fl/Federated_learning/Tdeeppath/temp/20220130-jsonline-visualize/work/97/68604acb77554207dbf27b830fe3e8

# %%
# !ls
# Out:
# abc.df	helper.py  out.jsonline  out.jsonline.png

# %%
import pandas as pd

# %%
df1 = pd.read_csv("abc.df", index_col=0)
#df2 = df1.sort_values('epoch')
df2 = df1

df3 = pd.melt(df2, ["epoch", "type"])

df3.head()
# Out:
#    epoch   type variable     value
# 0     85  train      acc  0.980556
# 1      9  train      acc  0.774856
# 2      6  train      acc  0.736515
# 3     17  train      acc  0.824495
# 4      1  train      acc  0.605966

# %%
import matplotlib.pyplot as plt
sns.set_palette("Blues")
plot = seaborn.lineplot('epoch', 'value', hue='variable', 
                        data=df3, style="type")
# Out:
# /mnt/GPU1-raid0/zhaomeng-from-GPU3/projects/20220128-fl/Federated_learning/Tdeeppath/temp/jsonline-visualizer-venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='acc'>
