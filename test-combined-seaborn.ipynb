# %%
import seaborn as sns
import matplotlib.pyplot as plt

file1 = "/mnt/GPU1-raid0/zhaomeng-from-GPU3/projects/20220128-fl/Federated_learning/Tdeeppath/temp/20220130-jsonline-visualize/work/c5/705748dae315649893b543c67f9ea8/combined.df"

# %%
import pandas as pd

# %%
df1 = pd.read_csv(file1, index_col=0)

# %%
df1.shape
# Out:
# (6724, 5)

# %%
df1.head()
# Out:
#    epoch   type variable     value                            name
# 0     85  train      acc  0.884467  config.15.20220208_220824.json
# 1      9  train      acc  0.687350  config.15.20220208_220824.json
# 2      6  train      acc  0.640116  config.15.20220208_220824.json
# 3     17  train      acc  0.737135  config.15.20220208_220824.json
# 4      1  train      acc  0.483563  config.15.20220208_220824.json

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, squeeze=True)

# %%
axes.flatten()
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
for n, name in enumerate(sorted(df1.name.unique())):
    sub_df = df1[df1.name==name]
    sns_plot = sns.lineplot(
        x="epoch",
        y="value",
        hue="variable",
        data=sub_df,
        style="type",
        palette="husl",
        ax=axes.flatten()[n],
    )

# %%
fig
